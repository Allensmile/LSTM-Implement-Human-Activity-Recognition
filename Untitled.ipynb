# %%
# !wget "https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI HAR Dataset.zip"
# !wget "https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI HAR Dataset.names"

# import copy
import os
from subprocess import call

print("")

print("Downloading...")
if not os.path.exists("UCI HAR Dataset.zip"):
    call(
        'wget "https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI HAR Dataset.zip"',
        shell=True
    )
    print("Downloading done.\n")
else:
    print("Dataset already downloaded. Did not download twice.\n")


print("Extracting...")
extract_directory = os.path.abspath("UCI HAR Dataset")
if not os.path.exists(extract_directory):
    call(
        'unzip -nq "UCI HAR Dataset.zip"',
        shell=True
    )
    print("Extracting successfully done to {}.".format(extract_directory))
else:
    print("Dataset already extracted. Did not extract twice.\n")
# Out:
# /bin/sh: wget: command not found
# /bin/sh: wget: command not found
#
# Downloading...
# ...
#
# Extracting...
# Extracting successfully done to /Users/youwei.tan/Downloads/LSTM-Human-Activity-Recognition-master/UCI HAR Dataset.

# %%
names = !ls /Users/youwei.tan/Downloads/*.mp3
names[:1]

import os
from IPython.display import display, Image
display(names[0])
# Out:
# '/Users/youwei.tan/Downloads/\xe5\xbc\xa0\xe6\x9d\xb0 - My Sunshine.mp3'

# %%
from urllib2 import Request, urlopen
import json

path1 = '42.974049,-81.205203|42.974298,-81.195755'
request=Request('http://maps.googleapis.com/maps/api/elevation/json?locations='+path1+'&sensor=false')
response = urlopen(request)
elevations = response.read()

pandas.io.json.json_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-cbf9ae27dcfa> in <module>()
#       4 path1 = '42.974049,-81.205203|42.974298,-81.195755'
#       5 request=Request('http://maps.googleapis.com/maps/api/elevation/json?locations='+path1+'&sensor=false')
# ----> 6 response = urlopen(request)
#       7 elevations = response.read()
#
# /Applications/anaconda/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /Applications/anaconda/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# ...

# %%
import pandas as pd

# elevations = {
#     "results" : {
#       {
#          "elevation" : 243.3462677001953,
#          "location" : {
#             "lat" : 42.974049,
#             "lng" : -81.205203,
#          },
#          "resolution" : 19.08790397644043
#       },
#       {
#          "elevation" : 244.1318664550781,
#          "location" : {
#             "lat" : 42.974298,
#             "lng" : -81.19575500000001
#          },
#          "resolution" : 19.08790397644043
#       },
#    },
#    "status" : "OK",
# }
import numpy as np


elevations = [{
    "created": "Fri Mar 13 18:09:33 GMT 2014",
    "description": "Tweeting the latest Playstation news!",
    "favourites_count": 4514,
    "followers": 235,
    "following": 1345,
    "geo_lat": 'null',
    "geo_long": 'null',
    "hashtags": "",
    "id": 2144411414,
    "is_retweet": 'false',
    "is_truncated": 'false',
    "lang": "en",
    "location": "",
    "media_urls": "",
    "mentions": "",
    "name": "Playstation News",
    "original_text": 'null',
    "reply_status_id": 0,
    "reply_user_id": 0,
    "retweet_count": 4514,
    "retweet_id": 0,
    "score": 0.0,
    "screen_name": "SevenPS4",
    "source": "<a href=\"http://twitterfeed.com\" rel=\"nofollow\">twitterfeed</a>",
    "text": "tweetinfohere",
    "timezone": "Amsterdam",
    "url": 'null',
    "urls": "http://bit.ly/1lcbBW6",
    "user_created": "2013-05-19",
    "user_id": 13313,
    "utc_offset": 3600
}]

#data = pd.read_csv()
import json

#pd.read_json('/Users/youwei.tan/Downloads/LSTM-Human-Activity-Recognition-master/data.txt')
pd.read_json(json.dumps(elevations))

#df = pd.read_json('http://platform.appcoachs.com/m/api/matrix')
# Out:
#                         created                            description  \
# 0  Fri Mar 13 18:09:33 GMT 2014  Tweeting the latest Playstation news!
#
#    favourites_count  followers  following geo_lat geo_long hashtags  \
# 0              4514        235       1345    null     null
#
#            id is_retweet     ...     score screen_name  \
# 0  2144411414      false     ...         0    SevenPS4
#
#                                               source           text  \
# 0  <a href="http://twitterfeed.com" rel="nofollow...  tweetinfohere
#
#     timezone   url                   urls  user_created  user_id  utc_offset
# 0  Amsterdam  null  http://bit.ly/1lcbBW6    2013-05-19    13313        3600
#
# [1 rows x 31 columns]

# %%
help(pd.read_json)
# Out:
# Help on function read_json in module pandas.io.json:
#
# read_json(path_or_buf=None, orient=None, typ='frame', dtype=True, convert_axes=True, convert_dates=True, keep_default_dates=True, numpy=False, precise_float=False, date_unit=None)
#     Convert a JSON string to pandas object
#
#     Parameters
#     ----------
#     path_or_buf : a valid JSON string or file-like, default: None
#         The string could be a URL. Valid URL schemes include http, ftp, s3, and
#         file. For file URLs, a host is expected. For instance, a local file
#         could be ``file://localhost/path/to/table.json``
#
#     orient
#
#         * `Series`
#
#           - default is ``'index'``
#           - allowed values are: ``{'split','records','index'}``
#           - The Series index must be unique for orient ``'index'``.
#
#         * `DataFrame`
#
#           - default is ``'columns'``
#           - allowed values are: {'split','records','index','columns','values'}
# ...

# %%
data = [{'state': 'Florida',
         'shortname': 'FL',
         'info': {'governor': 'Rick Scott'},
         'counties': [{'name': 'Dade', 'population': 12345},
                     {'name': 'Broward', 'population': 40000},
                     {'name': 'Palm Beach', 'population': ''}]},
        
        
        {'state': 'Ohio',
         'shortname': 'OH',
         'info': {'governor': 'John Kasich'},
         'counties': [{'name': 'Summit', 'population': 1234},
                      {'name': 'Cuyahoga', 'population': 1337}]}]

from pandas.io.json import json_normalize
result = json_normalize(data, 'counties', ['state', 'shortname', ['info', 'governor']])

result
# Out:
#          name population info.governor    state shortname
# 0        Dade      12345    Rick Scott  Florida        FL
# 1     Broward      40000    Rick Scott  Florida        FL
# 2  Palm Beach               Rick Scott  Florida        FL
# 3      Summit       1234   John Kasich     Ohio        OH
# 4    Cuyahoga       1337   John Kasich     Ohio        OH

# %%
data=[{"events": [
            {"schedule": {"date": "2015-08-27",
                          "location": {"building": "BDC", "floor": 5},  
                          "ID": 815
                         },
            "group": "A"},
            
            
            {"schedule": {"date": "2015-08-27",
                          "location": {"building": "BDC", "floor": 5},
                          "ID": 816},
             "group": "A"}]}]

# json_normalize(data, 'events', ['schedule',
#                                    ['schedule','location','building'], 
#                                    ['schedule','location','floor']])

json_normalize(data[0]["events"], "schedule", ['location']
                                  )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-2cac6a347246> in <module>()
#      16 #                                    ['schedule','location','floor']])
#      17
# ---> 18 json_normalize(data[0]["events"], "schedule", ['location']
#      19                                   )
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/io/json.pyc in json_normalize(data, record_path, meta, meta_prefix, record_prefix)
#     760                 records.extend(recs)
#     761
# --> 762     _recursive_extract(data, record_path, {}, level=0)
#     763
#     764     result = DataFrame(records)
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/io/json.pyc in _recursive_extract(data, path, seen_meta, level)
#     755                         meta_val = seen_meta[key]
#     756                     else:
# ...

# %%
json_normalize(data[0]['events'])
#data[0]
# Out:
#   group  schedule.ID schedule.date schedule.location.building  \
# 0     A          815    2015-08-27                        BDC
# 1     A          816    2015-08-27                        BDC
#
#    schedule.location.floor
# 0                        5
# 1                        5

# %%
import requests
#import arrow
# from pelecanus import PelicanJson
# from time import process_time
from pandas.io.json import json_normalize

matrix_url = "http://platform.appcoachs.com/m/api/matrix"
resp = requests.get(matrix_url)
if resp.status_code != 200:
    print("matrix api status code: ", resp.status_code)

body = resp.json()
# print(body)


result = json_normalize(body)
# with open('output', 'w') as FILE:
#    FILE.writelines(result)

result.columns = result.columns.map(lambda x: x.split(".")[-1])

# %%
json_normalize(body, 'adgroups')
#json_normalize(body['advertisers'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-77d63808629d> in <module>()
# ----> 1 json_normalize(body, 'adgroups')
#       2 #json_normalize(body['advertisers'])
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/io/json.pyc in json_normalize(data, record_path, meta, meta_prefix, record_prefix)
#     760                 records.extend(recs)
#     761
# --> 762     _recursive_extract(data, record_path, {}, level=0)
#     763
#     764     result = DataFrame(records)
#
# /Applications/anaconda/lib/python2.7/site-packages/pandas/io/json.pyc in _recursive_extract(data, path, seen_meta, level)
#     746         else:
#     747             for obj in data:
# --> 748                 recs = _pull_field(obj, path[0])
#     749
#     750                 # For repeating the metadata later
#
# ...

# %%
df = json_normalize(body['advertisers'])
json_normalize(df['products'][0])
# Out:
#                                              adgroups categories.brand  \
# 0   [{u'included_sites': {u'583396afe2fc1cb9578b45...               []
# 1   [{u'included_sites': {u'581ff4c3e2fc1c354e8b45...               []
# 2   [{u'included_sites': {}, u'bid_type': u'cpi', ...              NaN
# 3   [{u'included_sites': {u'581ff4c3e2fc1c354e8b45...              NaN
# 4   [{u'included_sites': {u'56847eb8e2fc1c601e8b45...              NaN
# 5   [{u'included_sites': {u'56aae67ee2fc1cb6628b45...              NaN
# 6   [{u'included_sites': {u'56aae67ee2fc1cb6628b45...              NaN
# 7   [{u'included_sites': {u'56aae67ee2fc1cb6628b45...              NaN
# 8   [{u'included_sites': {u'56aae67ee2fc1cb6628b45...              NaN
# 9   [{u'included_sites': {u'547863454a2a389e5d8b45...              NaN
# 10  [{u'included_sites': {u'581ff4c3e2fc1c354e8b45...              NaN
# 11  [{u'included_sites': {u'547863454a2a389e5d8b45...              NaN
# ...

# %%
test_data = str(body)
test_data = test_data.replace('[', '{')
test_data = test_data.replace(']', '}')
test_data[:55]
type(test_data)

#json.loads(test_data)
test_data
# Out:
# '{u\'advertisers\': {{u\'oid\': u\'546c3fd44a2a3810318b456b\', u\'products\': {{u\'official_url\': u\'https://play.google.com/store/apps/details?id=com.kaola\', u\'name\': u\'\\u7f51\\u6613\\u8003\\u62c9\', u\'reviewer_count\': None, u\'icon_url\': u\'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQ08NSkx56sow6xQr4EKXNK1BoAkSyYnOPFSGudgBNrD-lKjHqJ\', u\'oid\': u\'5836bd04e2fc1c1f048b456b\', u\'pid\': u\'SFerU6PD\', u\'max_install\': None, u\'score\': None, u\'pkg_name\': u\'\\u7f51\\u6613\\u8003\\u62c9\', u\'adgroups\': {{u\'video_ads\': {{u\'oid\': u\'5837ed1ee2fc1cac3c8b4567\', u\'ad\': {u\'in_line\': {u\'ad_title\': None, u\'extensions\': {u\'app_score\': None, u\'end_card\': True}, u\'description\': None, u\'creatives\': {{u\'linear\': {u\'duration\': u\'00:00:14\', u\'trackings\': {{u\'event\': u\'start\'}, {u\'event\': u\'firstQuartile\'}, {u\'event\': u\'midpoint\'}, {u\'event\': u\'thirdQuartile\'}, {u\'event\': u\'complete\'}}, u\'media_files\': {{u\'type\': u\'video/
# ...

# %%
json_normalize(df['products'][1])
# Out:
#                                             adgroups categories.games  \
# 0  [{u'included_sites': {}, u'bid_type': u'cpi', ...               []
#
#                                          description  \
# 0  十年武侠经典再续，2016年最受期待的3D真武侠手游《九阴真经3D》来了！360°无锁定自由...
#
#                                             icon_url max_install min_install  \
# 0  http://a3.mzstatic.com/us/r30/Purple42/v4/9d/e...        None        None
#
#                             name  \
# 0  九阴真经3D-端游十年经典 2016最受期待3D真武侠手游
#
#                                         official_url  \
# 0  https://itunes.apple.com/cn/app/jiu-yin-zhen-j...
#
#                         oid os.max_version.major os.max_version.minor  \
# 0  57c00a58e2fc1c42368b456a                 None                 None
#
#   os.max_version.patch  os.min_version.major  os.min_version.minor  \
# 0                 None                     6                     0
#
#   os.min_version.patch os.name       pid    pkg_name reviewer_count score
# ...

# %%
body
# Out:
# {u'advertisers': [{u'name': u'SE.test',
#    u'oid': u'546c3fd44a2a3810318b456b',
#    u'products': [{u'adgroups': [{u'bid_type': u'cpm',
#        u'campaign': {u'name': u'161125_\u7f51\u6613\u8003\u62c9APK CPM\u6d4b\u8bd5',
#         u'oid': u'5837a966e2fc1ce1778b4567'},
#        u'category_filters': {},
#        u'click_tracking_url': None,
#        u'excluded_sites': {},
#        u'image_ads': [{u'oid': u'5837ec95e2fc1cc11b8b4567',
#          u'size': {u'height': 1600, u'width': 900},
#          u'url': u'http://dl.appcoachs.net/default/5837/ec/89829619ed07a0df78768ccb96e6a0c6088a3ce2.jpeg'}],
#        u'included_sites': {u'583396afe2fc1cb9578b4567': {}},
#        u'name': u'161125_\u7f51\u6613\u8003\u62c9 apk',
#        u'oid': u'5837ec7de2fc1c88138b4567',
#        u'price': 1.3,
#        u'redirect_url': u'http://dik4wdc6quqor.cloudfront.net/android/kaola_3.3.2_dr_cpa_1.apk',
#        u'store': u'apk',
# ...

# %%
import pandas as pd
import requests

headers = {
    'Authorization': 'Bearer XXXXXXXXXXXXXXXXXXXXXXXXXXXXX',
    'Content-Type': 'application/json'
}

resp = requests.get('https://api.gitter.im/v1/rooms/554d218a15522ed4b3e02126/chatMessages', 
                    headers=headers)

# %%
resp.json()
# Out:
# {u'error': u'Unauthorized'}

# %%
import nose
  
from pandas import DataFrame
import numpy as np
  
import pandas.util.testing as tm
  
from pandas.io.json import json_normalize, nested_to_record
  
def _assert_equal_data(left, right):
    if not left.columns.equals(right.columns):
        left = left.reindex(columns=right.columns)
  
    tm.assert_frame_equal(left, right)
  
  
class TestJSONNormalize(tm.TestCase):
  
    def setUp(self):
        self.state_data = [
             {'counties': [{'name': 'Dade', 'population': 12345},
                           {'name': 'Broward', 'population': 40000},
                           {'name': 'Palm Beach', 'population': 60000}],
              'info': {'governor': 'Rick Scott'},
              'shortname': 'FL',
              'state': 'Florida'},
             {'counties': [{'name': 'Summit', 'population': 1234},
                           {'name': 'Cuyahoga', 'population': 1337}],
              'info': {'governor': 'John Kasich'},
              'shortname': 'OH',
              'state': 'Ohio'}]
  
    def test_simple_records(self):
        recs = [{'a': 1, 'b': 2, 'c': 3},
                {'a': 4, 'b': 5, 'c': 6},
                {'a': 7, 'b': 8, 'c': 9},
                {'a': 10, 'b': 11, 'c': 12}]
  
        result = json_normalize(recs)
        expected = DataFrame(recs)
  
        tm.assert_frame_equal(result, expected)
  
    def test_simple_normalize(self):
        result = json_normalize(self.state_data[0], 'counties')
        expected = DataFrame(self.state_data[0]['counties'])
        tm.assert_frame_equal(result, expected)
  
        result = json_normalize(self.state_data, 'counties')
  
        expected = []
        for rec in self.state_data:
            expected.extend(rec['counties'])
        expected = DataFrame(expected)
  
        tm.assert_frame_equal(result, expected)
  
        result = json_normalize(self.state_data, 'counties', meta='state')
        expected['state'] = np.array(['Florida', 'Ohio']).repeat([3, 2])
  
        tm.assert_frame_equal(result, expected)
  
    def test_more_deeply_nested(self):
        data = [{'country': 'USA',
                 'states': [{'name': 'California',
                             'cities': [{'name': 'San Francisco',
                                         'pop': 12345},
                                        {'name': 'Los Angeles',
                                         'pop': 12346}]
                            },
                            {'name': 'Ohio',
                             'cities': [{'name': 'Columbus',
                                         'pop': 1234},
                                        {'name': 'Cleveland',
                                         'pop': 1236}]}
                           ]
                 },
                {'country': 'Germany',
                 'states': [{'name': 'Bayern',
                             'cities': [{'name': 'Munich', 'pop': 12347}]
                            },
                            {'name': 'Nordrhein-Westfalen',
                             'cities': [{'name': 'Duesseldorf', 'pop': 1238},
                                        {'name': 'Koeln', 'pop': 1239}]}
                           ]
                 }
                ]
  
        result = json_normalize(data, ['states', 'cities'],
                                meta=['country', ['states', 'name']])
                                # meta_prefix={'states': 'state_'})
  
        ex_data = {'country': ['USA'] * 4 + ['Germany'] * 3,
                   'states.name': ['California', 'California', 'Ohio', 'Ohio',
                                   'Bayern', 'Nordrhein-Westfalen',
                                   'Nordrhein-Westfalen'],
                   'name': ['San Francisco', 'Los Angeles', 'Columbus',
                            'Cleveland', 'Munich', 'Duesseldorf', 'Koeln'],
                   'pop': [12345, 12346, 1234, 1236, 12347, 1238, 1239]}
  
        expected = DataFrame(ex_data, columns=result.columns)
        tm.assert_frame_equal(result, expected)
  
    def test_shallow_nested(self):
        data = [{'state': 'Florida',
                 'shortname': 'FL',
                 'info': {
                      'governor': 'Rick Scott'
                 },
                 'counties': [{'name': 'Dade', 'population': 12345},
                             {'name': 'Broward', 'population': 40000},
                             {'name': 'Palm Beach', 'population': 60000}]},
                {'state': 'Ohio',
                 'shortname': 'OH',
                 'info': {
                      'governor': 'John Kasich'
                 },
                 'counties': [{'name': 'Summit', 'population': 1234},
                              {'name': 'Cuyahoga', 'population': 1337}]}]
  
        result = json_normalize(data, 'counties',
                                ['state', 'shortname',
                                 ['info', 'governor']])
        ex_data = {'name': ['Dade', 'Broward', 'Palm Beach', 'Summit',
                            'Cuyahoga'],
                   'state': ['Florida'] * 3 + ['Ohio'] * 2,
                   'shortname': ['FL', 'FL', 'FL', 'OH', 'OH'],
                   'info.governor': ['Rick Scott'] * 3 + ['John Kasich'] * 2,
                   'population': [12345, 40000, 60000, 1234, 1337]}
        expected = DataFrame(ex_data, columns=result.columns)
        tm.assert_frame_equal(result, expected)
  
    def test_meta_name_conflict(self):
        data = [{'foo': 'hello',
                 'bar': 'there',
                 'data': [{'foo': 'something', 'bar': 'else'},
                          {'foo': 'something2', 'bar': 'else2'}]}]
  
        self.assertRaises(ValueError, json_normalize, data,
                          'data', meta=['foo', 'bar'])
  
        result = json_normalize(data, 'data', meta=['foo', 'bar'],
                                meta_prefix='meta')
  
        for val in ['metafoo', 'metabar', 'foo', 'bar']:
            self.assertTrue(val in result)
  
    def test_record_prefix(self):
        result = json_normalize(self.state_data[0], 'counties')
        expected = DataFrame(self.state_data[0]['counties'])
        tm.assert_frame_equal(result, expected)
  
        result = json_normalize(self.state_data, 'counties',
                                meta='state',
                                record_prefix='county_')
  
        expected = []
        for rec in self.state_data:
            expected.extend(rec['counties'])
        expected = DataFrame(expected)
        expected = expected.rename(columns=lambda x: 'county_' + x)
        expected['state'] = np.array(['Florida', 'Ohio']).repeat([3, 2])
  
        tm.assert_frame_equal(result, expected)
  
  
class TestNestedToRecord(tm.TestCase):
  
    def test_flat_stays_flat(self):
        recs = [dict(flat1=1,flat2=2),
                dict(flat1=3,flat2=4),
                ]
  
        result = nested_to_record(recs)
        expected = recs
        self.assertEqual(result, expected)
  
    def test_one_level_deep_flattens(self):
        data = dict(flat1=1,
                    dict1=dict(c=1,d=2))
  
        result = nested_to_record(data)
        expected =     {'dict1.c': 1,
             'dict1.d': 2,
             'flat1': 1}
  
        self.assertEqual(result,expected)
  
    def test_nested_flattens(self):
        data = dict(flat1=1,
                    dict1=dict(c=1,d=2),
                    nested=dict(e=dict(c=1,d=2),
                                d=2))
  
        result = nested_to_record(data)
        expected =     {'dict1.c': 1,
             'dict1.d': 2,
             'flat1': 1,
             'nested.d': 2,
             'nested.e.c': 1,
             'nested.e.d': 2}
  
        self.assertEqual(result,expected)

# if __name__ == '__main__':
#     nose.runmodule(argv=[__file__, '-vvs', '-x', '--pdb',
#                          '--pdb-failure', '-s'], exit=False)

# About Us (Contact Us) | Privacy | Twitter | Facebook | Feedback
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-c0a4af868ed2> in <module>()
#     208
#     209 # About Us (Contact Us) | Privacy | Twitter | Facebook | Feedback
# --> 210 t = TestNestedToRecord()
#     211 t.test_nested_flattens()
#
# /Applications/anaconda/lib/python2.7/unittest/case.pyc in __init__(self, methodName)
#     187         except AttributeError:
#     188             raise ValueError("no such test method in %s: %s" %
# --> 189                   (self.__class__, methodName))
#     190         self._testMethodDoc = testMethod.__doc__
#     191         self._cleanups = []
#
# ValueError: no such test method in <class '__main__.TestNestedToRecord'>: runTest

# %%
# 进入一个交互式 TensorFlow 会话.
import tensorflow as tf
sess = tf.InteractiveSession()

x = tf.Variable([1.0, 2.0])
a = tf.constant([3.0, 3.0])

init = tf.initialize_all_variables()
# 使用初始化器 initializer op 的 run() 方法初始化 'x' 
sess.run(init)

# 增加一个减法 sub op, 从 'x' 减去 'a'. 运行减法 op, 输出结果 
sub = tf.sub(x, a)
print sub.eval()
# ==> [-2. -1.]
# Out:
# [-2. -1.]
# Exception AssertionError: AssertionError("Nesting violated for default stack of <type 'weakref'> objects",) in <bound method InteractiveSession.__del__ of <tensorflow.python.client.session.InteractiveSession object at 0x119cb5550>> ignored
